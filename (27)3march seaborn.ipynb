# %% [markdown]
# ## Seaborn

# %% [markdown]
# ## Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# ## Name any five plots that we can plot using the Seaborn library

# %% [raw]
# Seaborn is a Python data visualization library built on top of Matplotlib that provides a high-level interface for creating informative and aesthetically pleasing statistical graphics.
# Here are five commonly used plots that can be created using Seaborn:
#
#     1. Scatter Plot:
#
#                 A scatter plot displays individual data points as dots on a two-dimensional plane, making it useful for visualizing the relationship between two continuous variables.
#
#     2. Line Plot:
#
#              Seaborn can be used to create line plots, which are particularly effective for visualizing trends or patterns over time or across categories.
#
#     3. Bar Plot:
#
#              Bar plots are used to display categorical data using rectangular bars. They are suitable for comparing different categories or groups.
#
#     4. Box Plot (or Box-and-Whisker Plot):
#
#                                     A box plot provides a visual summary of the distribution of a dataset, showing the median, quartiles, and potential outliers.
#
#     5. Violin Plot:
#
#                   A violin plot is a combination of a box plot and a kernel density plot. It displays the distribution of data across different categories.
#
#
#             These are just a few examples, and Seaborn offers a wide range of other plot types, including heatmap, pair plot, joint plot, and more.
#             Each plot type is designed to effectively visualize different aspects of the data, making Seaborn a versatile tool for data exploration and visualization.

# %% [markdown]
# ## Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x ="timepoint" and y = "signal" for different events and regions.
# ## Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
import seaborn as sns

# %%
f=sns.load_dataset("fmri")

# %%
f.head(2)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883

# %%
sns.pairplot(f)

# %% [markdown]
# ## Plot a line plot using x ="timepoint" and y = "signal" for different events and regions.

# %%
f.head(2)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883

# %%
sns.lineplot(x="timepoint", y="signal",style="event",hue="region",data=f)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ## Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.
#
# ## Note: pclass, age, and fare are columns in the titanic dataset.

# %%
t=sns.load_dataset("titanic")

# %%
t.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.boxplot(x="pclass",y="age", data=t)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x="pclass",y="fare", data=t)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# ## Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
d=sns.load_dataset("diamonds")

# %%
d.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
sns.histplot(data=d, x="price", kde=True, hue='cut')
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
sns.displot(d["price"])

# %% [markdown]
# ## Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
iris=sns.load_dataset("iris")

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.pairplot(data=iris,hue="species")

# %% [markdown]
# ## Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights=sns.load_dataset("flights")

# %%
flights.head(2)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %%
fd=flights.pivot("month", "year", "passengers")
# Out:
# /tmp/ipykernel_1231/2938509111.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fd=flights.pivot("month", "year", "passengers")

# %%
sns.heatmap(fd,annot=True,fmt="d", cmap='viridis')
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>
