# %% [markdown]
# ## MongoDB

# %% [markdown]
# # Q.1 What is MongoDB? Explain non-relational databases in short. In which scenarios it is preferred to use MongoDB over SQL databases?

# %% [raw]
# ##                                                                        MongoDB
#
#
#           MongoDB is a high-performance, open-source, document-oriented NoSQL database that provides a flexible, scalable, and high-performance solution for managing complex data.
#
#
#     A. Functions of MongoDB:
#                           i). Document-Oriented Storage:
#
#                                                        MongoDB stores data in BSON (Binary JSON) documents. These documents can contain a variety of data types, including strings,
#                                                       numbers, arrays, and even other documents. This flexibility allows for complex data structures to be represented.
#                          ii). Dynamic Schema:
#
#                                            Unlike traditional relational databases, MongoDB does not require a predefined schema. This allows for easy adaptation to evolving
#                                            data structures, making it well-suited for projects with changing requirements.
#
#                         iii). Replication and Failover:
#
#                                                       MongoDB supports replica sets, providing data redundancy and automatic failover in case of node failures.
#                                                        This ensures high availability and data durability.
#
#                         iv). Sharding for Scalability:
#
#                                                     MongoDB employs sharding to horizontally partition data across multiple nodes. This allows it to handle extremely large datasets
#                                                     and high write loads, ensuring scalability as the application grows.
#
#                         v). Rich Query Language:
#
#                                               MongoDB's query language supports a wide range of operations, including complex aggregations, geospatial queries, text search, and more.
#                                               This allows for efficient and flexible data retrieval.
#
#     B. Advantages of MongoDB:
#                            i). High Scalability:
#
#                                               MongoDB's distributed architecture allows it to scale horizontally by adding more nodes. This ensures that the database can handle
#                                               large volumes of data and high request rates.
#
#                           ii). Flexible Data Modeling:
#
#                                                     MongoDB's document-based model is well-suited for representing complex relationships and hierarchies. This makes it an excellent
#                                                     choice for applications with diverse and evolving data structures.
#
#                         iii). High Performance:
#
#                                               MongoDB's architecture, including features like in-memory processing, native indexing, and efficient storage formats, allows for high
#                                               throughput and low latency, especially in read-heavy workloads.
#
#                         iv). Geospatial Capabilities:
#
#                                                     With native geospatial indexes and queries, MongoDB excels in applications that require location-based data,
#                                                     such as mapping and tracking systems.
#
#
#     C. Disadvantages of MongoDB:
#
#                               i). Limited Transaction Support:
#
#                                                             MongoDB's transaction capabilities are not as robust as those of traditional relational databases.
#                                                             It doesn't support multi-document transactions across multiple collections.
#
#
#                              ii). Complexity in Data Modeling:
#
#                                                             While the flexibility of MongoDB is a strength, it can also lead to challenges in designing optimal data models,
#                                                             especially for developers transitioning from a relational database background.
#
#                             iii). Memory Consumption:
#
#                                                     MongoDB may be memory-intensive, particularly in scenarios with complex queries or large datasets.
#                                                     Adequate memory allocation is crucial for optimal performance.
#
#                             iv). Lack of Strict Data Integrity:
#
#                                                               MongoDB's flexible schema can lead to challenges in enforcing strict data integrity constraints.
#
#                                                               It relies on application-level validations for data consistency.
#
#     D. Use Cases for MongoDB:
#                           i). Content Management Systems (CMS):
#
#                                                             MongoDB's flexibility and scalability make it a popular choice for managing content in websites, blogs,
#                                                             and other content-rich applications.
#
#                           ii). Data Analytics and Business Intelligence:
#
#                                                                     MongoDB's ability to handle large volumes of data and perform complex queries makes
#                                                                     it suitable for analytics platforms and BI tools.
#
#                         iii). IoT and Time Series Data:
#
#                                                     MongoDB's ability to handle semi-structured data and its support for complex queries make it a good fit for
#                                                     IoT applications and time series data analysis.
#
#                          iv). Real-Time Applications:
#
#                                                     MongoDB's high throughput and low latency make it well-suited for real-time applications like messaging platforms,
#                                                     social media feeds, and gaming.
#
#
#
#     E. Security and Operations:
#                              i). Authentication and Authorization:
#
#                                                                   MongoDB provides robust authentication mechanisms, including SCRAM and x.509 certificates,
#                                                                   to control access to databases.
#                             ii). Encryption:
#
#                                            MongoDB supports encryption both at rest and in transit, ensuring data security.
#
#                             iii). Role-Based Access Control (RBAC):
#
#                                                                  By assigning specific roles to users, MongoDB allows fine-grained control over access to databases and collections.
#
#                             iv). Auditing and Logging:
#
#                                                  MongoDB's auditing feature enables tracking of operations and changes in the database, aiding in compliance and security efforts.
#
#
#     F. Conclusion:
#                 MongoDB is a versatile database system that excels in scenarios where flexibility, scalability, and high performance are critical.
#                 However, it's important to carefully evaluate its strengths and weaknesses in the context of specific project requirements before adoption. Proper data modeling,
#                 indexing, and operational best practices are key to maximizing the benefits of MongoDB in advanced use cases.

# %% [markdown]
# ## Explain non-relational databases in short.

# %% [raw]
# Non-relational databases, also known as NoSQL databases, are a category of database systems that do not adhere to the traditional relational database model.
# They are designed to handle large volumes of unstructured or semi-structured data and offer more flexibility in data modeling and scaling.
#
# Here are some key characteristics and examples of non-relational databases:
#
# 1.Flexible Data Models:
#
#                         NoSQL databases allow for more flexible data models, which can be document-based, key-value pairs, wide-column, or graph-based.
#                         This flexibility makes them well-suited for handling diverse data types.
#
#
# 2.Scalability:
#
#                 NoSQL databases are often designed to scale horizontally, meaning they can handle a high volume of traffic and data by distributing the load across multiple servers.
#                 This makes them suitable for large-scale applications.
#
#
# 3.High Performance:
#
#                     NoSQL databases are optimized for specific use cases, such as real-time applications, high-speed data retrieval, and high concurrency.
#                     They are often chosen for applications where performance is critical.
#
#
# 4.Schemaless:
#
#             Unlike relational databases, which require a predefined schema, NoSQL databases are schemaless. This means that data can be added and changed on the fly without
#             the need to define a fixed schema beforehand.
#
#
# 5.Examples of Non-Relational Databases:
#
#                     i).Document-Based Databases (e.g., MongoDB):
#
#                                         These store data in flexible, semi-structured documents (often JSON or BSON format). Each document can have a different structure,
#                                         allowing for dynamic schemas.
#
#
# Example:
#
# {
#   _id: 1,
#   name: "John Doe",
#   email: "john@example.com",
#   age: 30,
#   interests: ["programming", "gaming"]
# }
#
#
#                 ii).Key-Value Stores (e.g., Redis, Amazon DynamoDB):
#
#                                 These databases use a simple key-value pair for data storage. They are highly efficient for read and write operations.
#
#
# Example:
#
# Key: "user:1"
# Value: {
#   name: "Jane Smith",
#   email: "jane@example.com",
#   age: 25
# }
#
#
#                 iii).Wide-Column Stores (e.g., Cassandra, HBase):
#
#                                     These databases organize data in columns instead of rows, making them suitable for handling large amounts of data with high write throughput.
#
#
#
# Example:
#
# | User_ID | Name   | Email              |
# |---------|--------|---------------------|
# | 1       | Alice  | alice@example.com   |
# | 2       | Bob    | bob@example.com     |
#
#
#
#                 iv).Graph Databases (e.g., Neo4j):
#
#                                             These databases are optimized for representing and traversing complex relationships between entities.
#
# Example:
#
# (Alice) -[FRIENDS_WITH]-> (Bob)
# (Bob) -[FOLLOWS]-> (Charlie)
# (Charlie) -[LIKES]-> (Post)
#
#
# Non-relational databases are particularly useful in scenarios where the data is dynamic, unstructured, or needs to be scaled to handle a massive amount of traffic.
# They provide more flexibility in data modeling compared to traditional relational databases, making them a popular choice in modern application development.

# %% [markdown]
# ## In which scenarios it is preferred to use MongoDB over SQL databases?

# %% [raw]
# MongoDB is a popular NoSQL database that is preferred over traditional SQL databases in certain scenarios due to its specific strengths and capabilities.
#
#
# Here are some scenarios where MongoDB is often preferred:
#
#
# 1.Flexible Data Models:
#
#                         MongoDB uses a document-based data model, allowing for dynamic and flexible schemas. This makes it well-suited for applications where the data structure
#                         is subject to change or where the data is semi-structured or unstructured.
#
#
# 2.Scalability:
#
#                 MongoDB is designed for horizontal scalability, which means it can easily handle a high volume of traffic and large datasets. It is well-suited for applications
#                 that require scaling out across multiple servers.
#
#
# 3.Complex Data Structures:
#
#                             It excels in handling complex data structures, such as nested objects and arrays. This is particularly useful in scenarios where data is naturally
#                             hierarchical or deeply nested.
#
#
# 4.High Throughput and Low Latency:
#
#                                     MongoDB is optimized for high-speed read and write operations. It is suitable for real-time applications and scenarios where low latency is crucial.
#
#
# 5.Large Volumes of Data:
#
#                         MongoDB is efficient in handling large volumes of data, especially when it comes to unstructured or semi-structured data.
#                         It can handle high write throughput and is suitable for applications with big data requirements.
#
#
#
# 6.Use Cases with Rapid Development:
#
#                                     MongoDB is often preferred in agile development environments or projects with rapidly evolving requirements. Its schemaless nature allows for
#                                     quick iteration and adaptation to changing needs.
#
#
#
# 7.Geospatial Data and Location-Based Services:
#
#                                                 MongoDB provides native support for geospatial indexes and queries, making it an excellent choice for applications that involve
#                                                 geospatial data, such as location-based services, mapping, and tracking applications.
#
#
#
# 8.Content Management Systems (CMS):
#
#                                     MongoDB can be a good fit for content management systems where content is often dynamic and may have varying attributes.
#
#
#
# 9.Internet of Things (IoT):
#
#                             MongoDB is suitable for handling IoT data, which can be diverse, high-volume, and dynamic in nature. Its flexibility in data modeling and scalability
#                             are valuable in IoT applications.
#
#
#
# 10.Prototyping and MVP Development:
#
#                                     MongoDB is often favored in early-stage projects, prototypes, or Minimum Viable Products (MVPs) due to its ease of setup, flexibility,
#                                     and fast development cycle.
#
#
# It's important to note that the choice between MongoDB and SQL databases depends on the specific requirements and characteristics of the application. While MongoDB excels
# in certain scenarios, traditional SQL databases may be more suitable for structured, transactional data or scenarios where complex joins and ACID transactions are crucial.
# Ultimately, the decision should be based on a careful evaluation of the application's needs and design considerations.

# %% [markdown]
# # Q.2 State and explain the features of MongoDB.

# %% [raw]
#  A. State:
#           State refers to the current condition or status of a system, process, or entity at a particular point in time. It encompasses various attributes,
#           configurations, and data values that define the momentary state of a system. For example, in computing, the state of a program could include the values stored
#            in variables, the content of memory, and the current position of program execution.
#
#
#  B. MongoDB Features:
#
#                     1. Document-Oriented Storage:
#                                                 MongoDB stores data in BSON (Binary JSON) documents. These documents can contain a variety of data types, including strings,
#                                                 numbers, arrays, and even other documents. This flexibility allows for complex data structures to be represented.
#
#                     2. Dynamic Schema:
#                                       Unlike traditional relational databases, MongoDB doesn't require a predefined schema. This means that documents in a collection can have different
#                                       fields and structures, allowing for greater flexibility.
#
#                     3. Replication and Failover:
#                                                MongoDB supports replica sets, providing data redundancy and automatic failover in case of node failures.
#                                                This ensures high availability and data durability.
#
#                     4. Sharding for Scalability:
#                                                 MongoDB employs sharding to horizontally partition data across multiple nodes. This allows it to handle extremely large datasets
#                                                 and high write loads, ensuring scalability as the application grows.
#
#                     5. Rich Query Language:
#                                           MongoDB's query language supports a wide range of operations, including complex aggregations, geospatial queries, text search, and more.
#                                           This allows for efficient and flexible data retrieval.
#
#                     6. Geospatial Capabilities:
#                                               It includes native support for geospatial data and allows for efficient querying of location-based information.
#
#                     7. Ad Hoc Queries:
#                                      Developers can perform ad hoc queries on MongoDB without the need to pre-define a specific structure, which provides a flexible approach
#                                      to data retrieval.
#
#                     8. Load Balancing:
#                                         MongoDB's sharding capabilities allow for distributing data across multiple nodes, ensuring even distribution of the workload.
#
#                     9. GridFS:
#                                MongoDB provides GridFS, a specification for storing and retrieving large files such as images, videos, and audio files, which can exceed the
#                                 16MB BSON document size limit.
#
#                     10. Enterprise Features:
#                                            MongoDB Enterprise offers additional features like field-level encryption, LDAP/Active Directory integration, and auditing capabilities
#                                            for enhanced security and compliance.
#
# These features collectively make MongoDB a versatile and powerful choice for a wide range of use cases, particularly those that require flexible data modeling, high scalability,
#    and dynamic, evolving datasets.
#
#
#
#                     11. Indexes and Query Optimization:
#                                                      MongoDB supports various types of indexes, which can significantly improve query performance. Additionally,
#                                                      it provides tools for query optimization and profiling.
#
#                     12. Schema Evolution:
#                                          MongoDB allows for easy schema evolution, meaning that as application requirements change, the data model can be adapted
#                                          without downtime or complex migration procedures.
#
#                     13. Change Streams:
#                                       MongoDB's change streams allow applications to monitor real-time changes in the database. This is particularly useful for applications
#                                      that require reactive functionality based on database updates.
#
#                     14. Full-Text Search:
#                                         It offers a full-text search feature that allows for efficient and fast searching of text content within documents.
#
#                     15. Time-Series Collections:
#                                                MongoDB 5.0 introduced Time-Series Collections, which are optimized for storing and analyzing time-series data.
#                                                This is particularly valuable for IoT applications and monitoring systems.
#
#                     16. In-Memory Storage Engine:
#                                                 MongoDB's WiredTiger storage engine supports an in-memory mode, which can be utilized for workloads that require extremely
#                                                 low latency and high throughput.
#
#                     17. Database Triggers:
#                                          MongoDB Atlas, the managed database service for MongoDB, provides the capability to set up database triggers, allowing for automated
#                                          actions based on certain database events.
#
#                     18. Auto-Sharding:
#                                      MongoDB's built-in auto-sharding feature automatically distributes data across multiple nodes in a cluster, ensuring data is evenly
#                                      balanced and performance is optimized.
#
#                     19. Global Clusters and Zones:
#                                                  MongoDB enables the creation of global clusters and data zones, which can be beneficial for applications requiring data
#                                                  locality or compliance with regional data privacy laws.
#
#                     20. Retryable Writes:
#                                         MongoDB supports retryable writes, ensuring that write operations are either fully completed or not performed at all in the event of
#                                         network or server failures.
#
# These features further enhance MongoDB's suitability for a wide range of use cases, from high-velocity, data-intensive applications to complex, dynamic data models in a
#   distributed environment. It remains a popular choice for organizations seeking a versatile and scalable NoSQL database solution.

# %% [markdown]
# # Q.3 write a code to connect MongoDB to python. Also create a database and a collection in MongoDB.

# %% [markdown]
# ## write a code to connect MongoDB to python.

# %% [raw]
# To connect Python to MongoDB, we'll need the pymongo library. we can install it using pip:
#
#
# pip install pymongo
# Here's an example Python code to connect to MongoDB and perform basic operations:
#
#
# import pymongo
#
# 1.# Establish connection
# client = pymongo.MongoClient("mongodb://localhost:27017/")  # Connect to the default MongoDB instance
#
# 2.# Access a specific database
# db = client["mydatabase"]
#
# 3.# Create a collection (equivalent to a table in SQL)
# collection = db["mycollection"]
#
# 4.# Insert a document (equivalent to a row in SQL)
# document = {"name": "John Doe", "age": 30, "email": "john@example.com"}
# collection.insert_one(document)
#
# 5.# Query data
# result = collection.find_one({"name": "John Doe"})
# print(result)
#
# 6.# Update a document
# collection.update_one({"name": "John Doe"}, {"$set": {"age": 31}})
#
# 7.# Query updated data
# updated_result = collection.find_one({"name": "John Doe"})
# print(updated_result)
#
# 8.# Delete a document
# collection.delete_one({"name": "John Doe"})
#
# 9.# Close connection
# client.close()

# %% [raw]
# Explanation:
#
# 1.Establish Connection:
#
#                      a). pymongo.MongoClient() connects to the MongoDB instance. In this case, we're connecting to the default instance running on localhost at port 27017.
#
#                      b). In the previous response, step 1 involves establishing a connection to the MongoDB database using the pymongo library.
#
#
# Establish Connection (pymongo.MongoClient("mongodb://localhost:27017/")):
# This line of code creates a connection to the MongoDB database.
# The pymongo.MongoClient() function is used to establish a connection.
# The argument "mongodb://localhost:27017/" specifies the URL of the MongoDB server. In this case, it's connecting to the default instance running on the local machine (localhost)
# at port 27017.
#
# In summary, pymongo.MongoClient() establishes a connection to the MongoDB server, allowing your Python application to interact with the database. This is the first step in any
# MongoDB interaction from Python.
#
#
# 2.Access a Database:
#
#                     a). client["mydatabase"] accesses a specific database named mydatabase. If it doesn't exist, MongoDB will create it.
#
#                     b). In the previous response, step 2 involves accessing a specific database within the MongoDB server.
#
#
# Access a Database (client["mydatabase"]):
# This line of code accesses a specific database named mydatabase within the MongoDB server.
# If the database mydatabase does not exist, MongoDB will create it.
#
# In summary, client["mydatabase"] allows your Python application to work with a specific database within the MongoDB server. This step is necessary to perform operations such as
# creating collections, inserting data, and querying documents within that particular database.
#
#
# 3.Create a Collection:
#
#                         a).db["mycollection"] creates a collection (similar to a table in SQL) named mycollection within the mydatabase.
#
#                         b).In the previous response, step 3 involves creating a collection within the accessed database in MongoDB.
#
#
# Create a Collection (db["mycollection"]):
# This line of code creates a collection (similar to a table in SQL) named mycollection within the previously accessed database.
# If the collection mycollection does not exist, MongoDB will create it.
#
# In summary, db["mycollection"] establishes a collection where you can store and manage documents. This is essential for organizing and working with data within a specific database
# in MongoDB.
#
#
#
# 4.Insert a Document:
#
#                     a).collection.insert_one(document) inserts a document (similar to a row in SQL) into the collection.
#
#                     b).In the previous response, step 4 involves inserting a document into the created collection in MongoDB.
#
#
# Insert a Document (collection.insert_one(document)):
# This line of code inserts a document (similar to a row in SQL) into the collection.
# The insert_one() method is used to insert a single document.
#
# In summary, collection.insert_one(document) allows you to add data to the collection. A document is a JSON-like object that contains the data you want to store.
# This is a fundamental operation for populating a collection with data in MongoDB.
#
#
# 5.Query Data:
#
#             a).collection.find_one({"name": "John Doe"}) queries the collection for a document where the name field is "John Doe".
#
#             b).In the previous response, step 5 involves querying data from the collection in MongoDB.
#
#
# Query Data (collection.find_one({"name": "John Doe"})):
# This line of code queries the collection for a document where the name field is "John Doe".
# The find_one() method is used to retrieve a single document that matches the specified query criteria.
#
# In summary, collection.find_one({"name": "John Doe"}) allows you to retrieve data from the collection based on specified criteria. This is an essential operation for retrieving
# specific documents or records from a MongoDB collection.
#
# 6.Update a Document:
#
#                     a). collection.update_one({"name": "John Doe"}, {"$set": {"age": 31}}) updates a document, setting the age field to 31.
#
#                     b).In the previous response, step 6 involves updating a document within the collection in MongoDB.
#
#
# Update a Document (collection.update_one({"name": "John Doe"}, {"$set": {"age": 31}})):
# This line of code updates a document that matches the query condition. In this case, it's updating a document where the name is "John Doe".
# The update_one() method is used to update a single document.
# The {"$set": {"age": 31}} part specifies that the age field should be updated to 31.
#
# In summary, collection.update_one() allows you to modify the content of a document in the collection. This is an important operation for keeping the data up-to-date in MongoDB.
#
#
#
# 7.Delete a Document:
#
#                     a).collection.delete_one({"name": "John Doe"}) deletes a document.
#
#                     b).In the previous response, step 7 involves deleting a document from the collection in MongoDB.
#
#
# Delete a Document (collection.delete_one({"name": "John Doe"})):
# This line of code deletes a document that matches the query condition. In this case, it's deleting a document where the name is "John Doe".
# The delete_one() method is used to delete a single document.
#
# In summary, collection.delete_one() allows you to remove a specific document from the collection. This operation is essential for managing and maintaining the data within
# a MongoDB collection.
#
#
# 8.Close Connection:
#
#                     a).client.close() closes the connection to MongoDB.
#
#                     b).In the previous response, step 8 involves closing the connection to the MongoDB database. This is important to free up system resources and ensure proper
#                         cleanup after you've finished using the database.
#
#
# Close Connection (client.close()):
# This line of code calls the close() method on the MongoDB client object (client).
# It effectively terminates the connection between your Python application and the MongoDB database.
# Closing the connection is good practice to prevent any potential resource leaks or issues related to leaving connections open unnecessarily.
#
#
# In summary, client.close() ensures that the connection is properly closed, releasing any resources associated with it. This is an important step to maintain the efficiency and
# reliability of your application.
#
#
#
# *****In this example, we're using a fictitious database named mydatabase and a collection named mycollection. We insert a document, query it, update it, and then delete it.
# These are some of the basic operations you can perform with MongoDB using Python. Remember to replace the database and collection names with your actual database and collection names.

# %% [markdown]
# ## Also create a database and a collection in MongoDB.

# %%
import pymongo

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
client=pymongo.MongoClient("mongodb+srv://best:bestpw@cluster0.jmhh6zp.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client.test

# %%
db=client["Mongo_Assignment"]

# %%
coll_Mongo_Assignment=db["python"]

# %% [markdown]
# # Q.4 Using the database and the collection created in question number 3, write a code to insert one record, and insert many records. Use the find() and find_one() methods to print the inserted recored.

# %%
data1={"name":"soumadip","phone_no":13232424,"address":"medinipur"}

# %%
data2=[{"country":"India","state":"west bengal","pin":1313},{"temp":23,"soil":"sand and muddy"}]

# %%
coll_Mongo_Assignment.insert_one(data1)

# %%
coll_Mongo_Assignment.insert_many(data2)

# %%
for i in coll_Mongo_Assignment.find():
    print(i)
# Out:
# {'_id': ObjectId('653cfc3fd1ab1c63e29db392'), 'name': 'soumadip', 'phone_no': 13232424, 'address': 'medinipur'}
# {'_id': ObjectId('653cfd6bd1ab1c63e29db393'), 'country': 'India', 'state': 'west bengal', 'pin': 1313}
# {'_id': ObjectId('653cfd6bd1ab1c63e29db394'), 'temp': 23, 'soil': 'sand and muddy'}

# %%
coll_Mongo_Assignment.find_one()
# Out:
# {'_id': ObjectId('653cfc3fd1ab1c63e29db392'),
#  'name': 'soumadip',
#  'phone_no': 13232424,
#  'address': 'medinipur'}

# %% [markdown]
# # Q.5 Explain how you can use the find() method to  query the MongoDB Database. Write a simple code to demonstrate this.

# %% [raw]
# To query a MongoDB database using the find() method, you use the PyMongo library in Python. The find() method is used to retrieve documents from a collection
# that match a specified query criteria. Here's a brief explanation of how to use it:

# %% [raw]
# 1. Connecting to the Database:
#
# Before querying the database, you need to establish a connection to MongoDB
# from pymongo import MongoClient
#
# # Connect to MongoDB
# client = MongoClient('mongodb://localhost:27017/')
# db = client['my_database']
# collection = db['my_collection']

# %% [raw]
# 2. Using the find() Method:
#
# The find() method is applied to a collection and takes a query parameter to specify the criteria for the search. It returns a cursor object that allows you to iterate over the results.
#
# # Basic find() query
# result = collection.find({"key": "value"})

# %% [raw]
# 3. Iterating Over the Results:
#
# Once you have the result, you can iterate over it to access the matching documents:
# for document in result:
#     print(document)

# %% [raw]
# 4. Filtering and Projection:
#
# You can use various query operators to filter documents, and you can also use projection to specify which fields to include or exclude:
#   # Filtering using $gt (greater than) operator
# result = collection.find({"age": {"$gt": 30}})
#
# # Projection to include only specific fields
# result = collection.find({}, {"name": 1, "age": 1})

# %% [raw]
# 5. Limiting the Number of Results:
#
# You can limit the number of documents returned using the limit() method:
#  result = collection.find().limit(5)

# %% [raw]
# 6. Sorting Results:
#
# You can use the sort() method to order the results:
#  # Sorting by age in descending order
# result = collection.find().sort("age", -1)

# %% [raw]
# 7. Counting Matching Documents:
#
# You can use the count_documents() method to get the count of matching documents:
# count = collection.count_documents({"status": "active"})

# %% [raw]
# 8. Closing the Connection:
#
# Once you're done with your operations, remember to close the connection:
# client.close()

# %% [raw]
# Remember to replace 'mongodb://localhost:27017/', 'my_database', and 'my_collection' with your actual MongoDB connection string, database name, and collection name.
#
# These are the basic steps to use the find() method to query a MongoDB database using Python and PyMongo. It allows you to retrieve, filter, and manipulate data stored in
# the MongoDB collections.

# %%
for i in coll_Mongo_Assignment.find({"country":"India"}):
    print(i)
# Out:
# {'_id': ObjectId('653cfd6bd1ab1c63e29db393'), 'country': 'India', 'state': 'west bengal', 'pin': 1313}

# %% [markdown]
# # Q.6 Explain the sort() method. Give an example to demonstrate sorting in MongoDB.

# %% [raw]
# The sort() method in MongoDB is used to sort the documents in a collection based on specified criteria. It allows you to control the order in which documents are
# returned in the result set. Here's a brief explanation of how the sort() method works:
#
#     1. Syntax:
#
#                   The sort() method takes one or more fields and their respective sort order (ascending or descending) as parameters. It has the following syntax:
#
#
#                          db.collection_name.find().sort({ field1: order1, field2: order2, ... })
#                          field1, field2, etc.: The fields by which you want to sort the documents.
#                         order1, order2, etc.: The sort order for each field. Use 1 for ascending order and -1 for descending order.
#
#
#     2. Example:
#             Let's say you have a collection named users with documents containing name and age fields. You want to retrieve the documents sorted by age in descending order:
#
#                db.users.find().sort({ age: -1 })
#
#                   This query will return the documents from the users collection sorted by age in descending order.
#
#
#     3. Multi-key Sorting:
#
#                          You can sort by multiple fields in MongoDB. In this case, documents are first sorted by the first field, and then within each group of documents
#                          with the same value for the first field, they are sorted by the second field, and so on.
#
#
#                           db.users.find().sort({ field1: order1, field2: order2 })
#                           For example, to sort by age in descending order and then by name in ascending order:
#
#
#                           db.users.find().sort({ age: -1, name: 1 })
#
#     4. Sorting by Nested Fields:
#
#                              You can also sort by fields within nested objects. For example, if you have a document structure like:
#                              {
#                               name: "John Doe",
#                               address: {
#                               city: "New York",
#                               state: "NY"
#                                 }
#                                }
#                             You can sort by address.city:
#
#
#                            db.users.find().sort({ "address.city": 1 })
#
#     5. Limiting the Number of Results:
#
#                                      You can combine sort() with limit() to retrieve a specific number of sorted documents:
#
#
#                                      db.users.find().sort({ age: -1 }).limit(5)
#
#
#     6. Note:
#
#            The sort() method does not modify the documents in the collection; it only affects the order in which they are returned in the query result.
#
#             If an index exists for the field(s) you are sorting by, MongoDB can use it to efficiently perform the sorting operation.
#
#            The sort() method is a powerful tool for controlling the order of documents returned in MongoDB queries, allowing you to retrieve data in a meaningful and organized manner.

# %% [markdown]
# # Q.7 Explain why delete_one(), delete_many(), and drop() is used.

# %% [raw]
# In MongoDB, delete_one(), delete_many(), and drop() are methods used for removing documents or entire collections from a database. Here's a brief explanation of each:
#
# A.  delete_one():
#
#               The delete_one() method is used to delete a single document from a collection that matches a specified filter.
#
#                Example:
#
#
#                       db.collection_name.delete_one({ key: value })
#                        This will delete the first document that matches the specified filter.
#
#             Use Case:
#                      When you want to remove a specific document that meets certain criteria.
#
#
# B. delete_many():
#
#                  The delete_many() method is used to delete multiple documents from a collection that match a specified filter.
#
#                 Example:
#                  db.collection_name.delete_many({ key: value })
#                  This will delete all documents that match the specified filter.
#
#             Use Case:
#                      When you want to remove multiple documents that meet certain criteria.
#
# C. drop():
#
#           The drop() method is used to remove an entire collection from the database.
#
#                  Example:
#
#
#               db.collection_name.drop()
#               This will completely remove the collection, including all of its documents.
#
#           Use Case:
#                    When you want to permanently delete an entire collection and all of its associated data.
#
#            Note:
#                Be cautious when using drop(), as it irreversibly deletes the collection. It should be used with care, especially in production environments.
#
# These methods provide different levels of granularity when it comes to removing data from a MongoDB database:
#
# Use delete_one() when you want to remove a specific document.
# Use delete_many() when you want to remove multiple documents that match a filter.
# Use drop() when you want to remove an entire collection.
# It's important to use these methods with care, especially drop(), as it permanently deletes data. Always make sure to have backups and consider the potential impact
#   on your application before executing these operations.
